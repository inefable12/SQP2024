� ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸
# ...

# %%
# !ollama run llama3.1 "halla el módulo del vector 3i +4j" > modulo_consulta.txt
# Out:
# ⠙

# %%
# !cat modulo_consulta.txt
# Out:
# Para encontrar el módulo (o magnitud) de un vector en un espacio cartesiano, se utiliza la fórmula:
#
# |vector| = √(x² + y² + z²)
#
# donde x, y y z son las componentes del vector en el eje i, j y k respectivamente.
#
# En su caso, el vector es 3i + 4j. Como solo hay dos componentes (x=3 y y=4), y no hay componente en la dirección del eje k (z=0 por defecto), se simplifica a:
#
# |vector| = √(x² + y²)
#        = √(3² + 4²)
#        = √(9 + 16)
#        = √25
#        = 5
#
# Por lo tanto, el módulo del vector 3i + 4j es 5.

# %%
# !ls *.txt
# Out:
# articulo1.txt  binario.txt  modulo_consulta.txt

# %%
# !ollama run llama3.1 "Eres un especialista en redacción de artículos científicos. Resume en 100 palabras en español el artículo científico del siguiente archivo: $(cat articulo1.txt)"
# Out:
# ⠙ The study investigates the effect of iron on the antibacterial activity of
# tetracyclines, specifically doxycycline and minocycline, against Aggregatib
# Aggregatibacter actinomycetemcomitans, a bacterium associated with periodon
# periodontal disease.
#
# Key findings:
#
# 1. Tetracyclines have strong iron-chelating activity.
# 2. The presence of iron increases the MICs (Minimum Inhibitory Concentratio
# Concentrations) of doxycycline and minocycline against A. actinomycetemcomi
# actinomycetemcomitans.
# 3. The effect of iron on tetracycline activity is strain-dependent, with on
# one strain (ATCC 29522) showing a significant increase in MICs in the prese
# presence of iron, while another strain (Y4) showed only a slight reduction.
# reduction.
# 4. A much lower concentration of doxycycline or minocycline is re
# required to inhibit growth of A. actinomycetemcomitans in an iron-restricte
# iron-restricted environment than in an iron-rich environment.
#
# ...

# %%
lista_preguntas = ["Resume en español en 50 palabras el artículo científico del siguiente archivo: ",
                  "Responde en español Cual es el principal descubrimiento en el artículo del siguiente archivo: "]

# %%
for pregunta in lista_preguntas:
    # !ollama run llama3.1 "{pregunta} $(cat articulo1.txt)"
# Out:
# ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠋ ⠹ ⠹ ⠼ ⠴ ⠴ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠋ ⠹ The passage discusses research on the properties and mechanisms of action o
# of tetracycline antibiotics, specifically doxycycline and minocycline, agai
# against Aggregatibacter actinomycetemcomitans (A. actinomycetemcomitans), a
# a bacterium associated with periodontal disease.
#
# The key findings are:
#
# 1. Tetracyclines possess iron-chelating activity, forming complexes with me
# metallic cations like iron.
# 2. The presence of iron can affect the susceptibility of A. actinomycetemco
# actinomycetemcomitans to doxycycline and minocycline, with lower concentrat
# concentrations required in an iron-restricted environment.
# 3. The study suggests that the iron-chelating activity of tetracyclines may
# may contribute to their antimicrobial action by making less iron available
# to bacteria, which is essential for bacterial growth.
#
# ...
